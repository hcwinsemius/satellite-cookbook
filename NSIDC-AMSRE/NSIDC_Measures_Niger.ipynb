# %% [markdown]
# ## Download, slice, concatenate and store data from the National Snow and Ice Data Center ##
# This recipe demonstrates how you can prepare a nicely formatted yearly organised set of properly formatted NetCDF files from the NSIDC database "Measures". The recipe is tested on AMSR-E data (6.25Km) and set up to allow for variations in frequency, Ascending/Descending orbits and Horizontal / Vertical polarization. These settings are used to construct download urls which are then retrieved using wget behind the scenes. If you are using windows, please retrieve a wget .exe for your system from https://eternallybored.org/misc/wget/
#
# Information about datasets that may also be retrieved (but may require different settings and projection information) can be found on the NSIDC pages for each product for instance http://nsidc.org/data/nsidc-0630
#
# To make the recipe work for tour product of interest, a reconstruction of a proper url template is needed. Have a look in the code below to adapt that.

# %%
# %reload_ext autoreload
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import os
import cartopy
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER

import matplotlib.pyplot as plt
import xarray as xr
import pyproj
import osr
import datetime
import subprocess
import shutil
import numpy as np

# import our own small lib
import nsidc
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
os.path.abspath('/')
# Out:
# 'd:\\'

# %% [markdown]
# First, construct a bunch of settings for your specific data of interest. The idea is to construct urls in a loop by filling in a template, and retrieve these urls. Then read them, manipulate them and store them separately.
# - supply your own nasa earthdata username and password.
# - fill in the required bits and pieces to retrieve the right data for your case (Change template accordingly)
# In the case below, we vary the url string accoding to frequency, polarization, orbit and time span. This may be different for your use case.

# %%
url_base = 'https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/'
url_folder = '{:s}/'
url_template = url_base + url_folder + 'NSIDC-0630-EASE2_T{:s}km-AQUA_AMSRE-{:s}-{:s}{:s}-{:s}-{:s}-v1.3.nc'
download_template = 'wget --http-user={:s} --http-password={:s} --load-cookies mycookies.txt --save-cookies mycookies.txt --keep-session-cookies --no-check-certificate --auth-no-challenge -r --reject "index.html*" -np -e robots=off {:s}'

fn_out_template = 'NSIDC-0630-EASE2_T{:s}km-AQUA-AMSRE-{:s}{:s}-{:s}_{:04d}.nc'
out_path = os.path.abspath('netcdf')
if not(os.path.isdir(out_path)):
    # prepare the output path
    os.makedirs(out_path)
freq = '36' # 36 GhZ following Brakenridge 2007 (WRR M/C ratio paper)
res = 25  # can also be 12.5 or 25, although this depends on the chosen frequency as well
# freq = '23' # 36 GhZ following Brakenridge 2007 (WRR M/C ratio paper)
HV = 'V' # Horizontal polarisation
AD = 'D' # Ascending or descending, descending contains imagery during the day, probably showing more contrast

# start_date = datetime.datetime(2002, 6, 1)
start_date = datetime.datetime(2007, 1, 1)
# end_date = datetime.datetime(2002, 6, 5)  # only a few days to make a demonstration
end_date = datetime.datetime(2011, 12, 31)  # use this end date to cover the whole AMSR-E period.
step = datetime.timedelta(days=1)  # M

try:
    credential_fn = os.path.abspath('../../nsidc_credentials.txt')
    with open (credential_fn, 'r') as f:
        data = f.readline()
        username, password = data.split(',')
#     username, password = str(np.loadtxt(credential_fn, dtype=np.str)).split(',')
except:
    print('No credential file found, please put a txt file with <user>,<pass> in {:s}'.format(credential_fn))

# %% [markdown]
# We also need some information on geographical coverage. What bounding box would you like to retrieve? We need a projection method from latlon to the projection of the dataset itself to accomodate a proper geographical slicing. In the nsidc.py lib, a number of projection routines is provided to accomodate moving from one projection to the other.

# %%
# define the proj4string belonging to the grids you are downloading. You can find these in a downloaded sample 
# under the variable/attribute crs.proj4text. Here we simply copy-paste that.
proj4str = '+proj=cea +lat_0=0 +lon_0=0 +lat_ts=30 +x_0=0 +y_0=0 +ellps=WGS84 +datum=WGS84 +units=m'
points_interest = [(2.4406387000000223, 6.893251099999999),
                   (2.2999999999999545, 7.099999999999999),
                   (2.4851462999999967, 8.0335995),
                   (2.0499999999999545, 7.566667)
]

# In this example, we are interested in parts of West-Africa, so we provide a bounding box covering that in the format
# [(xmin, ymin), (xmax, ymax)]
bounds = [(-5., 0.),
          (10., 15.),
         ]

bounds = [(-10., 11.),
          (1.,18.),
          ]  # Niger

# bounds = [(20., -20.),
#           (40., -8.),
#          ]  # alternative bounds around Zambezi river basin


# we define a projection object for lat-lon WGS84 (EPSG code 4326)
proj_out = pyproj.Proj(init='epsg:4326')
# we define a projection object for the projection used in the downloaded grids.
proj_in = pyproj.Proj(proj4str)

# here we convert the coordinates in lat-lon into the coordinate system of the downloaded grids.
bounds_xy = nsidc.proj_coords(bounds, proj_out, proj_in)
points_xy = nsidc.proj_coords(points_interest, proj_out, proj_in)

# now we're all set!

# %% [markdown]
# We have all information we need. Now we just need a nice loop with some intelligence when to write a file. We write it on annual basis. You can adapt this of course. Some important things:
# - we need to be able to track the location of the download and construct a proper file name. We do this by stripping parts of the url.
# - after retrieval and massaging, we need to throw away the downloaded stuff. We also strip the folder structure so that we can delete this after we're done with a file.
# - the files are apparently not entirely CF-compliant. There is a conflicting missing_value and _FillValue number. In our example, the _FillValue represented the right missing, so we simply overwrite the missing_value attribute by the _FillValue attribute in a small function correct_miss_fill. We return a cf decoded dataset from that function. This is nice because it interprets dates and times very nicely.
# - this part takes a long time if you decide to download a large dataset!! So please first test it on only a small part of the world or a few time slices.

# %%
dt = start_date
list_ds = []
year = dt.year # let's store data per year

while dt <= end_date:
    url = nsidc.make_measures_url(url_template, res, dt, freq, HV, AD)  # make the url string to download
    fn = url.strip('https://')  # strip https:// from the url to get the local location of the downloaded file
    path = fn.split('/')[0]  # split fn in little pieces on / and keep only the 0-th indexed piece (main folder)
    download = nsidc.make_measures_download(download_template, url, username, password)  # pass the url to a download string template
    success = subprocess.call(download)  # call the download string in a command-line (use wget.exe! get it from online)
    if success == 0:
        print('Retrieved {:s}'.format(url))
        # the file was successfully downloaded (if not zero, there was a problem or file is sinmply not available)
        # read file, cut a piece and add it to our list of time steps
        ds = xr.open_dataset(fn, decode_cf=False)
        ds_sel = nsidc.select_bounds(ds, bounds_xy)
        list_ds.append(ds_sel.load())  # load the actual data so that we can delete the original downloaded files
        ds.close()
        shutil.rmtree(path)  # we're done cutting part of the required grid, so throw away the originally downloaded world grid.
    dt += step   # increase by one day to go for the next download day.
    if (year != dt.year) or (dt > end_date):  # store results if one moves to a new year or the end date is reached
        # concatenate the list of timesteps into a new ds
36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.10.24/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007297-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.10.25/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007298-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.10.26/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007299-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.10.27/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007300-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.10.28/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007301-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.10.29/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007302-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.10.30/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007303-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.10.31/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007304-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.11.01/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007305-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.11.02/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007306-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.11.03/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007307-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.11.04/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007308-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.11.05/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007309-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.11.06/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007310-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.11.07/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007311-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.11.08/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007312-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.11.09/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007313-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.11.10/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007314-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.11.11/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007315-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.11.12/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007316-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.11.13/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007317-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.11.14/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007318-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.11.15/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007319-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.11.16/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007320-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.11.17/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007321-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.11.18/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007322-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.11.19/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007323-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.11.20/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007324-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.11.21/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007325-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.11.22/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007326-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.11.23/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007327-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.11.24/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007328-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.11.25/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007329-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.11.26/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007330-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.11.27/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007331-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.11.28/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007332-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.11.29/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007333-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.11.30/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007334-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.12.01/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007335-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.12.02/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007336-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.12.03/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007337-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.12.04/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007338-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.12.05/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007339-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.12.06/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007340-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.12.07/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007341-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2007.12.08/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2007342-36V-D-GRD-RSS-v1.3.nc
# ...
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.05.16/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011136-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.05.17/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011137-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.05.18/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011138-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.05.19/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011139-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.05.20/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011140-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.05.21/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011141-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.05.22/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011142-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.05.23/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011143-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.05.24/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011144-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.05.25/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011145-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.05.26/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011146-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.05.27/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011147-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.05.28/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011148-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.05.29/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011149-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.05.30/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011150-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.05.31/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011151-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.06.01/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011152-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.06.02/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011153-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.06.03/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011154-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.06.04/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011155-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.06.05/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011156-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.06.06/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011157-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.06.07/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011158-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.06.08/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011159-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.06.09/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011160-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.06.10/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011161-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.06.11/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011162-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.06.12/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011163-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.06.13/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011164-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.06.14/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011165-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.06.15/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011166-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.06.16/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011167-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.06.17/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011168-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.06.18/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011169-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.06.19/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011170-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.06.20/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011171-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.06.21/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011172-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.06.22/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011173-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.06.23/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011174-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.06.24/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011175-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.06.25/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011176-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.06.26/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011177-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.06.27/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011178-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.06.28/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011179-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.06.29/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011180-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.06.30/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011181-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.07.01/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011182-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.07.02/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011183-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.07.03/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011184-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.07.04/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011185-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.07.05/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011186-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.07.06/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011187-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.07.07/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011188-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.07.08/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011189-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.07.09/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011190-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.07.10/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011191-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.07.11/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011192-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.07.12/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011193-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.07.13/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011194-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.07.14/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011195-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.07.15/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011196-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.07.16/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011197-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.07.17/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011198-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.07.18/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011199-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.07.19/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011200-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.07.20/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011201-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.07.21/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011202-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.07.22/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011203-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.07.23/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011204-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.07.24/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011205-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.07.25/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011206-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.07.26/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011207-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.07.27/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011208-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.07.28/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011209-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.07.29/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011210-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.07.30/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011211-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.07.31/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011212-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.08.01/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011213-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.08.02/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011214-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.08.03/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011215-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.08.04/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011216-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.08.05/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011217-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.08.06/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011218-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.08.07/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011219-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.08.08/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011220-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.08.09/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011221-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.08.10/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011222-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.08.11/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011223-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.08.12/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011224-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.08.13/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011225-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.08.14/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011226-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.08.15/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011227-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.08.16/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011228-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.08.17/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011229-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.08.18/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011230-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.08.19/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011231-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.08.20/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011232-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.08.21/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011233-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.08.22/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011234-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.08.23/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011235-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.08.24/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011236-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.08.25/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011237-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.08.26/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011238-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.08.27/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011239-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.08.28/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011240-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.08.29/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011241-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.08.30/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011242-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.08.31/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011243-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.09.01/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011244-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.09.02/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011245-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.09.03/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011246-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.09.04/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011247-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.09.05/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011248-36V-D-GRD-RSS-v1.3.nc
# Retrieved https://n5eil01u.ecs.nsidc.org/MEASURES/NSIDC-0630.001/2011.09.06/NSIDC-0630-EASE2_T25km-AQUA_AMSRE-2011249-36V-D-GRD-RSS-v1.3.nc

# %% [markdown]
# Ok, we should have some data now. Let's see if we can make a plot over a geographical map to demonstrate. We plot the first time step of brightness temperature in the last saved file below.

# %%
ds = xr.open_dataset(fn_out)
ax = plt.axes(projection=ccrs.PlateCarree())
# ax.add_feature(cfeature.LAND)
# ax.add_feature(cfeature.OCEAN)
# get a mesh of the coordinates in grid's projection
xi, yi = np.meshgrid(ds.x, ds.y)

# the chosen projection is not (yet) supported by caropy.crs, so we need to do the transformation ourselves for now. 
# No biggy, here we go
loni, lati = pyproj.transform(proj_in, proj_out, xi, yi)

# now drape the data on the map
p = ax.pcolormesh(loni, lati, ds['TB'][-1], transform=ccrs.PlateCarree())

# also plot some points of interest 
# ax = nsidc.plot_points(ax, points_interest, marker='x', color='k', linewidth=0., transform=ccrs.PlateCarree())
plt.colorbar(p, label='K')
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=1, color='gray', alpha=0.5, linestyle=':')
gl.xlabels_top = False
gl.ylabels_right = False
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER

# Gracefully close ds
ds.close()

# %% [markdown]
# Looks good, now we can start playing with the data in follow-up notebooks.

# %%
ds = xr.open_dataset(fn_out)
ds.TB[-1].plot()
